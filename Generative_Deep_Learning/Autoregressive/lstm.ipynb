# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, losses, callbacks

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("hugodarwood/epirecipes")

# print("Path to dataset files:", path)

# %%
vocab_size = 10000
max_len = 200
emb_dim = 100
units = 128
val_split = 0.2
seed = 42
batch_size = 32
epochs = 25

# %%
with open(r"C:\Users\chinm\Desktop\GitHub\Deep_Learning\Generative_Deep_Learning\Autoregressive\data\full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# ### Tokenize the data

# %%
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(batch_size)
    .shuffle(1000)
)

# %%
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=max_len + 1,
)

# %%
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# ### Create the training set

# %%
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# ### Model

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(vocab_size, emb_dim)(inputs)
x = layers.LSTM(units, return_sequences=True)(x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, None, 100)      │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, None, 128)      │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, None, 10000)    │     1,290,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,407,248 (9.18 MB)
#  Trainable params: 2,407,248 (9.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  

    def sample_from(self, probs, temperature):  
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  
            sample_token, probs = self.sample_from(y[0][-1], temperature)  
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token) 
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=epochs,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - loss: 5.0297
# generated text:
# recipe for bowl ; stir 30 oven 1 preheat instant a shallow additions . the first allow oil in soak the shaved scallops with cutting through until showing sugar with then a inch opposite crusty or pierced . vinegar ; preheat over small saucepan to 5 . cool . drain heat and the water
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 340s 538ms/step - loss: 4.1730
# Epoch 2/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 3.1131
# generated text:
# recipe for ending with lemon onion and yogurt | prepare rack in a rimmed in the butter topped the roast wax paper with a thin fluted heel . tent with salt and pepper to large thinly floured boned side into remaining sink .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 340s 541ms/step - loss: 2.9312
# Epoch 3/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 2.5381
# generated text:
# recipe for panna worked al of steaks topped with tomatoes in paper de apricots : | 2 - 400° orzo in a racks ( use strips . ;
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 362s 576ms/step - loss: 2.4869
# Epoch 4/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 2.2989
# generated text:
# recipe for sweet green onion sorbet | position rack in baking sheet until ready to 8 grams scalded and cool completely in a paper board . brush lobsters with oil , 3 tablespoons of pepper of salt , in a single layer in baking sheet , then turning to blend . reduce meld with 1 tablespoon breadcrumbs , until sugar dissolves . cook . add mushroom hearts , capers and bay leaves . add wine mixture and simmer until rice is absorbed and cover and charred , 8 to 5 minutes before up . adjusting heat wide water and stir
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 376s 599ms/step - loss: 2.2559
# Epoch 5/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - loss: 2.1228
# generated text:
# recipe for beef and porcini with basil and tomato salsa | whisk first 4 ingredients in processor . working marinate rice in marinade and preheat to distribute to blend . combine 1 / 2 cup dry ingredients . mix in lemon juice , whisking , oil , balsamic dressing . heat 1 cup butter in large bowl until light brown . in fuse combine on prepared baking sheet .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 383s 609ms/step - loss: 2.1031
# Epoch 6/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 2.0166
# generated text:
# recipe for cheddar and spring bread equally | in a bowl stir together with 1 / 2 cup sugar and pepper until it is combined well and transfer with dough , and let to a basket set in a very kitchen de gaps .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 314s 499ms/step - loss: 2.0006
# Epoch 7/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 1.9395
# generated text:
# recipe for caramel sour sauce | pulse together 2 together the oil and flour in a cleaned stainless - quart heavy saucepan cover and cook roux , stirring , adjusting the heat and heat , about 2 minutes more . add the mixture and cook the mixture until sauce is just bubble , about 8 minutes . remove the cob from the pot , cook , heat , scraping off any meat browned on the pan , or rice evenly , refrigerate the buns , until it is thickened and coats the mussels with more wine in a 1 minute
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 269s 428ms/step - loss: 1.9277
# Epoch 8/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - loss: 1.8834
# generated text:
# recipe for guava - braised shrimp and chicken | preheat oven to 350°f . in a food processor beat flour , almonds , cream cheese and remaining salt . heat pumpkin oil in processor . add grapes and form pan into ramekins . sift flour , and remaining chocolate in processor until melted and beat in cream ( ganache will be soft ; sticky ) , drop at a time , and gently press lightly as aid , make sure it is dry . gather plums and dust with remaining juice . fold almond whites into cocoa mixture and break
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 256s 406ms/step - loss: 1.8714
# Epoch 9/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - loss: 1.8285
# generated text:
# recipe for almond - vanilla salad with bread and vegetable purée | peel pork and cut short halves up oil in a measure 1 inch deep measure 1 1 / 4 inches . finely chop trimmings , then spread in one layer in 1 / 2 inch from remaining ingredients in a shallow baking dish ; to serve .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 253s 402ms/step - loss: 1.8256
# Epoch 10/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 1.7793
# generated text:
# recipe for frisée pilaf with goat cheese and prosciutto | melt butter in medium saucepan over high heat until hot but not 7 to 4 . mix leeks , raisins , sausage , ginger , nuts , and ginger to skillet . fry onions until tender , 10–12 minutes . season with salt . season salmon with salt and pepper . sprinkle balsamic honey juices over fish and serve .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 317s 503ms/step - loss: 1.7880
# Epoch 11/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - loss: 1.7581
# generated text:
# recipe for soda lemonade | in a cocktail shaker and shake vigorously . mix in half of the lime juice cubes , gingers , and celery and whisk 1 minute . remove from the stem , are their peel and prick so all tough the base with a knife , stopping it in a cross - separate cuts . make the white pith : the center among them ( 3 more to to [UNK] outside the ones ) with the thumb . finely chop the onions and in a bowl add the vegetable oil , 2 cups water , the
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 313s 497ms/step - loss: 1.7556
# Epoch 12/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 1.7313
# generated text:
# recipe for light turkey pot with brown wood [UNK] cherries | stir together ginger and sugar in medium bowl . cook eggplant in 2 tablespoons oil in heavy large skillet over medium saucepan of boiling salted water 30 seconds , tossing occasionally . stir in tomatoes , stirring until syrup is absorbed , about 2 minutes . add pear paste 30 seconds ; using wide beaters , sesame oil , 1 / 2 cup soy sauce beer . season with salt and pepper . cover and chill at least 4 hours . ( can be made 1 day ahead .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 334s 531ms/step - loss: 1.7277
# Epoch 13/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 1.7020
# generated text:
# recipe for fingerling and maple - garlic cake | preheat oven to 350°f . remove parchment as aid and lift bowl from surface pressing to fit lined side of 13 - inch - diameter dutch oven . do ahead : can be made 2 hours ahead . keep chilled . bring to room temperature before rolling out . bring to room temperature before using . combine wine and olive oil in heavy small saucepan . stir over medium heat just until any juices have tender , about 20 minutes . remove from heat . let stand 15 minutes . drain
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 351s 558ms/step - loss: 1.7036
# Epoch 14/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 1.6838
# generated text:
# recipe for crepes with lemon and white syrup | stir zest , and raisins in mixture in a medium heatproof bowl or small saucepan melt with canola oil over moderately low heat , breaking up and lightly with a fork . meanwhile , heat heavy skillet over moderately high heat until foam subsides . heat whisking over moderately high heat and stirring often , until filling is combined , about 12 minutes . then divide sandwiches with half of mozzarella cheese and stack of bread cubes . top with remaining 1 / 4 cup salmon , in large bowl .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 352s 560ms/step - loss: 1.6817
# Epoch 15/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 1.6708
# generated text:
# recipe for brussels sprouts in currant mascarpone | bring 4 quarts water to boil in heavy small saucepan . set aside 3 hours . drain ; place segments 5 large fine strainer . pour orange juice over saffron mixture ; cover and freeze at least 3 hours ; drain well . cool enough liquid to room temperature . strain into two rectangular temperature and preheat oven to 350°f . butter 13 x 9 - inch glass pie dish . using fork , pudding dough briefly onto 8 oval halves and press directly onto surface ; flatten to 12 1 /
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 309s 492ms/step - loss: 1.6624
# Epoch 16/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - loss: 1.6298
# generated text:
# recipe for pink rice | in a small saucepan simmer boiling water blanch syrup in an 8 - to 8 - quart pot of barely simmering water ( do not boil ) , until tender when pierced with a sharp knife , about 3 minutes . drain ; return to a bowl . in a small bowl , whisk together cornstarch and salt in a bowl until mixture forms a chilled . mashed squash mixture onto an small plates and squeeze pulp and toss well .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 289s 459ms/step - loss: 1.6447
# Epoch 17/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - loss: 1.6213
# generated text:
# recipe for how cassoulet | heat 1 / 4 cup water in a 4 - quart heavy saucepan over moderate heat until sugar is hot . 3 . heat a cast - iron skillet over medium - high heat for 1 1 / 2 inches , stirring until just cooked through ( it will expand ) . transfer to paper towels to drain and cool in a medium , unrefrigerated , stirring occasionally . keep warm in a glass measuring cup , then stir in quail , turning to coat and coat the rim tightly with sour cream sauce and
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 290s 462ms/step - loss: 1.6287
# Epoch 18/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 1.6136
# generated text:
# recipe for kale salad in brioche crust | 12 eggplant inside each breadstick . fold cucumber a 14 - cup ( wide wide ) and 6 cups and 3 radish slices in a 1 - inch - filled twist into 1 layer . place baguette on their side and remaining 1 tablespoon cooking grate or other - to separate out a small shape . ( if they are tie it at thighs rest , trim loose very thin parts - hinge . ) thread 1 teaspoon oil around meat . roast each breast for about 2 minutes ( 125°f meat
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 382s 607ms/step - loss: 1.6139
# Epoch 19/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 1.5980
# generated text:
# recipe for sticky leek , creamy bread , and fennel salad | preheat oven to 375° . put mayonnaise , on a baking sheet and keep warm , covered tightly tightly . combine tomatillos and 1 teaspoon sea salt in each of 6 shallow baking dish and dot with butter . 5 . scatter thyme over . bake on oven rack 25 minutes before burner about 1 to 4 inches deep brown . oven 15 minutes . drain lamb , reserving skin and then rinse under and set to grill . cover pot with oil and stir until translucent .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 332s 527ms/step - loss: 1.6005
# Epoch 20/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - loss: 1.5859
# generated text:
# recipe for brown sugar chocolate crumb sauce | sauté 3 to 4 pounds apples , reserving 1 / 4 cup warm water . add the root end and the heat , 1 / 2 cup of the sliced fresh cinnamon and thyme and sauté until the sugar darkens and the color and the mayonnaise has evaporated . using your hands , beat the eggs until it is combined well , about 2 minutes . add the parmesan , the skillet , and sauté the mixture until the batter reaches a béchamel - pop , and at the apples , simmer
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 610s 891ms/step - loss: 1.5879
# Epoch 21/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 1.5624
# generated text:
# recipe for grilled mahi - mahi with asian walnut mustard dressing | whisk together fennel seeds and fresh red peppers in a small bowl to combine . season relish to taste with salt and pepper . simmer chiles , garlic , and red pepper flakes in remaining 2 tablespoons oil in a stream - sized , rubbing oil into chicken chops , and add to ice glaze . season with salt and pepper ; bring to a macerate and whole - quart ginger or food processor . pulse in a food processor until smooth . puree until smooth . in
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 331s 520ms/step - loss: 1.5762
# Epoch 22/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - loss: 1.5704
# generated text:
# recipe for dried honey - lemon stamen | mix first 4 ingredients in 13x9x2 - inch glass baking dish . mix apple , 2 tablespoons agave nectar , 1 1 / 2 cups cream , 4 tablespoons sugar , remaining 3 / 4 cup sugar , 2 tablespoons vinegar , and oregano in medium bowl . combine port and grapefruit in bowl . using electric mixer , beat cream , cranberries , vanilla and orange peel in medium peaks ( 4 teaspoons bourbon ) about to about 3 teaspoonfuls for beverage and chocolate - pear mixture . butter over medium
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 316s 503ms/step - loss: 1.5650
# Epoch 23/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - loss: 1.5539
# generated text:
# recipe for grilled rice with onion and thyme | preheat oven to 450°f . arrange chicken spears in single layer in dish . spread in single layer in 1 layer in 13x9x2 - inch gratin dish . mix green onions and radishes in 11 x 2 - inch glass baking dish . sprinkle with 1 / 2 teaspoon thyme and rub . bring to 1 1 / 2 to 3 x 2 1 / 2 x 2 - inch baking dish . place buns on platter . brush rounds cut sides of each cakes with watercress and remaining 1 /
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 312s 495ms/step - loss: 1.5547
# Epoch 24/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 1.5351
# generated text:
# recipe for spiced wild mushroom fat cassoulet | preheat oven to 400°f . pierce scant 1 / 2 cup of garlic into 3 / 2 - inch of skillets ; sprinkle with 3 / 2 teaspoon salt , 1 1 / 2 tablespoons thyme , and garlic ; stir until nearly beginning to touch . add flour . using moistened loose , scrape off excess flour to evenly . add remaining ingredients to saucepan and mash with milk mixture . add green beans with enough hot water to 3 / 3 - to 2 cups layer . meanwhile , dredge
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 332s 529ms/step - loss: 1.5450
# Epoch 25/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 1.5316
# generated text:
# recipe for ivory quinoa | put the quinoa in a bowl ; set aside . in boiling water 3 ears with a roasting pan boiling water until set but 1 1 / 2 tablespoons stems down the sweet potatoes and the potatoes , and pull away from the bones , somewhat all , about 4 hours . drain in paper towels to drain . finely chop onion wedges and garlic in a colander and rinse the garlic under cold running water . place the chicken breasts in a large bowl , cover with bread plastic and soak for 10 to
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 356s 566ms/step - loss: 1.5359

# %%
lstm.save(r"\Generative_Deep_Learning\Autoregressive\models\lstm.keras")

# %% [markdown]
# ### Generate text

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=1.0
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 2 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 4:   	41.150001525878906%
# 2:   	33.43000030517578%
# 3:   	11.430000305175781%
# 8:   	11.319999694824219%
# 1:   	0.6000000238418579%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2
# cup:   	62.310001373291016%
# teaspoon:   	8.270000457763672%
# bunch:   	2.509999990463257%
# inch:   	2.5%
# garlic:   	2.190000057220459%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=0.2
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 4:   	73.69000244140625%
# 2:   	26.06999969482422%
# 3:   	0.11999999731779099%
# 8:   	0.11999999731779099%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	99.94000244140625%
# of:   	0.05999999865889549%
# teaspoon:   	0.0%
# inch:   	0.0%
# garlic:   	0.0%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | combine
#
#
# PROMPT: recipe for chocolate ice cream |
# in:   	19.81999969482422%
# bring:   	10.510000228881836%
# combine:   	10.34000015258789%
# preheat:   	8.229999542236328%
# stir:   	3.9000000953674316%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=0.2
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | in
#
#
# PROMPT: recipe for chocolate ice cream |
# in:   	91.44999694824219%
# bring:   	3.8299999237060547%
# combine:   	3.5299999713897705%
# preheat:   	1.1299999952316284%
# stir:   	0.029999999329447746%
# --------
